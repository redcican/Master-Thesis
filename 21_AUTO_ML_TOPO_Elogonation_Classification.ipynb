# %%
from __future__ import print_function

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tpot import TPOTClassifier


import time

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# %%
df = pd.read_csv('Elongation_class.CSV')
df.head()
# Out:
#       C    SI    MN      P      S    CU     MG     CR     NI     PB     AL  \
# 0  3.56  2.83  0.34  0.013  0.009  0.05  0.052  0.041  0.029  0.001  0.011
# 1  3.58  2.79  0.28  0.012  0.010  0.05  0.051  0.046  0.029  0.002  0.010
# 2  3.59  2.99  0.34  0.013  0.007  0.07  0.064  0.048  0.031  0.003  0.012
# 3  3.69  2.92  0.36  0.014  0.009  0.06  0.049  0.048  0.034  0.004  0.009
# 4  3.64  3.00  0.41  0.012  0.009  0.06  0.038  0.046  0.032  0.005  0.010
#
#       MO     TI     SN      V     ZN     CE  ElongOK
# 0  0.004  0.008  0.004  0.004  0.001  0.006        1
# 1  0.005  0.007  0.004  0.004  0.001  0.006        1
# 2  0.016  0.007  0.005  0.004  0.002  0.007        1
# 3  0.015  0.008  0.004  0.004  0.002  0.006        1
# 4  0.005  0.007  0.004  0.005  0.095  0.007        1

# %%
X = np.array(df.values[:, :-1])
y = np.array((df['ElongOK']).values)
print(X.shape, y.shape)
# Out:
# (385, 17) (385,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (308, 17) (308,) (77, 17) (77,)

# %%
tpot = TPOTClassifier(verbosity=2, max_time_mins=30, cv=10, n_jobs=-1)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
# Out:
# Optimization Progress: 100%|██████████| 200/200 [00:28<00:00,  2.38pipeline/s]
# Generation 1 - Current best internal CV score: 0.970840053763441
# Optimization Progress: 100%|██████████| 300/300 [00:44<00:00,  2.85pipeline/s]
# Generation 2 - Current best internal CV score: 0.970840053763441
# Optimization Progress: 100%|██████████| 400/400 [01:13<00:00,  1.23pipeline/s]
# Generation 3 - Current best internal CV score: 0.970840053763441
# Optimization Progress: 100%|██████████| 500/500 [01:43<00:00,  1.07pipeline/s]
# Generation 4 - Current best internal CV score: 0.970840053763441
# Optimization Progress: 100%|██████████| 600/600 [02:02<00:00,  1.07pipeline/s]
# Generation 5 - Current best internal CV score: 0.970840053763441
# Optimization Progress: 100%|██████████| 700/700 [02:29<00:00,  1.61s/pipeline]
# Generation 6 - Current best internal CV score: 0.970840053763441
# Optimization Progress: 100%|██████████| 800/800 [02:58<00:00,  1.31s/pipeline]
# Generation 7 - Current best internal CV score: 0.970840053763441
# Optimization Progress: 100%|██████████| 900/900 [03:25<00:00,  1.13s/pipeline]
# Generation 8 - Current best internal CV score: 0.9709408602150538
# Optimization Progress: 100%|██████████| 1000/1000 [03:49<00:00,  1.15pipeline/s]
# Generation 9 - Current best internal CV score: 0.9709408602150538
# Optimization Progress: 100%|██████████| 1100/1100 [04:13<00:00,  1.16pipeline/s]
# Generation 10 - Current best internal CV score: 0.9709408602150538
# Optimization Progress: 100%|██████████| 1200/1200 [04:39<00:00,  1.79pipeline/s]
# Generation 11 - Current best internal CV score: 0.9709408602150538
# Optimization Progress: 100%|██████████| 1300/1300 [05:04<00:00,  1.43pipeline/s]
# Generation 12 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 1400/1400 [05:30<00:00,  1.38pipeline/s]
# Generation 13 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 1500/1500 [06:04<00:00,  1.09s/pipeline]
# Generation 14 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 1600/1600 [06:29<00:00,  1.48pipeline/s]
# Generation 15 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 1700/1700 [06:57<00:00,  1.01pipeline/s]
# Generation 16 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 1800/1800 [07:20<00:00,  1.43pipeline/s]
# Generation 17 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 1900/1900 [07:57<00:00,  1.18s/pipeline]
# Generation 18 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 2000/2000 [08:21<00:00,  1.08s/pipeline]
# Generation 19 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 2100/2100 [08:49<00:00,  1.15pipeline/s]
# Generation 20 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 2200/2200 [09:22<00:00,  1.20s/pipeline]
# Generation 21 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 2300/2300 [09:59<00:00,  1.57s/pipeline]
# Generation 22 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 2400/2400 [10:22<00:00,  1.08pipeline/s]
# Generation 23 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 2500/2500 [10:57<00:00,  1.47s/pipeline]
# Generation 24 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 2600/2600 [11:33<00:00,  1.45s/pipeline]
# Generation 25 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 2700/2700 [11:55<00:00,  1.09s/pipeline]
# Generation 26 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 2800/2800 [12:18<00:00,  1.19pipeline/s]
# Generation 27 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 2900/2900 [12:51<00:00,  1.14s/pipeline]
# Generation 28 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 3000/3000 [13:24<00:00,  1.11s/pipeline]
# Generation 29 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 3100/3100 [14:01<00:00,  1.32s/pipeline]
# Generation 30 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 3200/3200 [14:26<00:00,  1.01pipeline/s]
# Generation 31 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 3300/3300 [14:50<00:00,  1.47pipeline/s]
# Generation 32 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 3400/3400 [15:15<00:00,  1.15s/pipeline]
# Generation 33 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 3500/3500 [15:54<00:00,  1.62s/pipeline]
# Generation 34 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 3600/3600 [16:29<00:00,  1.38s/pipeline]
# Generation 35 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 3700/3700 [16:59<00:00,  1.24s/pipeline]
# Generation 36 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 3800/3800 [17:28<00:00,  1.13s/pipeline]
# Generation 37 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 3900/3900 [17:54<00:00,  1.62pipeline/s]
# Generation 38 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 4000/4000 [18:21<00:00,  1.26s/pipeline]
# Generation 39 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 4100/4100 [18:53<00:00,  1.34pipeline/s]
# Generation 40 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 4200/4200 [19:28<00:00,  1.19pipeline/s]
# Generation 41 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 4300/4300 [19:57<00:00,  1.31pipeline/s]
# Generation 42 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 4400/4400 [20:39<00:00,  1.35s/pipeline]
# Generation 43 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 4500/4500 [21:15<00:00,  1.24s/pipeline]
# Generation 44 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 4600/4600 [21:58<00:00,  1.07s/pipeline]
# Generation 45 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 4700/4700 [22:26<00:00,  2.29pipeline/s]
# Generation 46 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 4800/4800 [22:51<00:00,  1.89pipeline/s]
# Generation 47 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 4900/4900 [23:27<00:00,  1.58pipeline/s]
# Generation 48 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 5000/5000 [23:53<00:00,  1.77pipeline/s]
# Generation 49 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 5100/5100 [24:18<00:00,  1.68pipeline/s]
# Generation 50 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 5200/5200 [24:54<00:00,  2.82pipeline/s]
# Generation 51 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 5300/5300 [25:17<00:00,  2.16pipeline/s]
# Generation 52 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 5400/5400 [25:40<00:00,  2.11pipeline/s]
# Generation 53 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 5500/5500 [26:07<00:00,  1.41pipeline/s]
# Generation 54 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 5600/5600 [26:34<00:00,  1.96pipeline/s]
# Generation 55 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 5700/5700 [26:57<00:00,  2.49pipeline/s]
# Generation 56 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 5800/5800 [27:28<00:00,  1.67pipeline/s]
# Generation 57 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 5900/5900 [27:59<00:00,  2.09pipeline/s]
# Generation 58 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 6000/6000 [28:23<00:00,  2.29pipeline/s]
# Generation 59 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 6100/6100 [28:51<00:00,  2.00pipeline/s]
# Generation 60 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 6200/6200 [29:15<00:00,  2.10pipeline/s]
# Generation 61 - Current best internal CV score: 0.9740658602150537
# Optimization Progress: 100%|██████████| 6300/6300 [29:38<00:00,  2.16pipeline/s]
# Generation 62 - Current best internal CV score: 0.9740658602150537
# 30.144511083333335 minutes have elapsed. TPOT will close down.
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: GradientBoostingClassifier(input_matrix, learning_rate=0.01, max_depth=6, max_features=0.35, min_samples_leaf=7, min_samples_split=15, n_estimators=100, subsample=0.3)
# 0.935064935065

# %%
tpot.export('tpot_car_pipeline.py')
# Out:
# True

# %%
print(tpot.score(X_test,y_test))
# Out:
# 0.935064935065

# %%
print(tpot.fitted_pipeline_)
# Out:
# Pipeline(memory=None,
#      steps=[('gradientboostingclassifier', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.01, loss='deviance', max_depth=6,
#               max_features=0.35000000000000003, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,...      presort='auto', random_state=None, subsample=0.3, verbose=0,
#               warm_start=False))])
